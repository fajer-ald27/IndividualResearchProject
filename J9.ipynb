# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv("effective_cell_throughput.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-2a6510879827> in <module>()
# ----> 1 df=pd.read_csv("effective_cell_throughput.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.head()
# Out:
#                      starttime              ecgi                    stoptime  \
# 0  Jan 31, 2022 @ 23:55:00.000  2708756710728449  Feb 1, 2022 @ 00:00:00.000
# 1  Jan 31, 2022 @ 23:55:00.000  2708756710728449  Feb 1, 2022 @ 00:00:00.000
# 2  Jan 31, 2022 @ 23:55:00.000  2708756710728449  Feb 1, 2022 @ 00:00:00.000
# 3  Jan 31, 2022 @ 23:55:00.000  2708756710728449  Feb 1, 2022 @ 00:00:00.000
# 4  Jan 31, 2022 @ 23:55:00.000  2708756710728449  Feb 1, 2022 @ 00:00:00.000
#
#   min5_effective_dl_cell_throughput_per_qci  \
# 0                                         -
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -
#
#   min5_effective_ul_cell_throughput_per_qci total_cell_pdcp_dl_volume_qci  \
# 0                                         -                             0
# 1                                         -                             0
# ...

# %%
df = df.drop('stoptime', axis = 1)

# %%
df = df.drop('total_cell_pdcp_dl_volume_qci', axis = 1)

# %%
df = df.drop('total_cell_pdcp_ul_volume_qci', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46159 entries, 0 to 46158
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   starttime                                  46159 non-null  object
#  1   ecgi                                       46159 non-null  int64
#  2   min5_effective_dl_cell_throughput_per_qci  46159 non-null  object
#  3   min5_effective_ul_cell_throughput_per_qci  46159 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.4+ MB

# %%
df['ecgi']=df['ecgi'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46159 entries, 0 to 46158
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   starttime                                  46159 non-null  object
#  1   ecgi                                       46159 non-null  category
#  2   min5_effective_dl_cell_throughput_per_qci  46159 non-null  object
#  3   min5_effective_ul_cell_throughput_per_qci  46159 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.1+ MB

# %%
test=df.copy()

# %%
test['starttime'] = test['starttime'].astype('str')

# %%
st=[]
for i in test['starttime'].values:
  i=str(i)
  i=i.replace('@',' ')
  st.append(i)

# %%
st
# Out:
# ['Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
#  'Jan 31, 2022   23:55:00.000',
# ...

# %%
test['starttime']=st

# %%
test['starttime']=pd.to_datetime(test['starttime'])

# %%
test['starttime'].dt.date
# Out:
# 0        2022-01-31
# 1        2022-01-31
# 2        2022-01-31
# 3        2022-01-31
# 4        2022-01-31
#             ...
# 46154    2022-01-30
# 46155    2022-01-30
# 46156    2022-01-30
# 46157    2022-01-30
# 46158    2022-01-30
# Name: starttime, Length: 46159, dtype: object

# %%
test.head()
# Out:
#             starttime              ecgi  \
# 0 2022-01-31 23:55:00  2708756710728449
# 1 2022-01-31 23:55:00  2708756710728449
# 2 2022-01-31 23:55:00  2708756710728449
# 3 2022-01-31 23:55:00  2708756710728449
# 4 2022-01-31 23:55:00  2708756710728449
#
#   min5_effective_dl_cell_throughput_per_qci  \
# 0                                         -
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -
#
#   min5_effective_ul_cell_throughput_per_qci
# 0                                         -
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46159 entries, 0 to 46158
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   starttime                                  46159 non-null  datetime64[ns]
#  1   ecgi                                       46159 non-null  category
#  2   min5_effective_dl_cell_throughput_per_qci  46159 non-null  object
#  3   min5_effective_ul_cell_throughput_per_qci  46159 non-null  object
# dtypes: category(1), datetime64[ns](1), object(2)
# memory usage: 1.1+ MB

# %%
test.value_counts()
# Out:
# starttime            ecgi              min5_effective_dl_cell_throughput_per_qci  min5_effective_ul_cell_throughput_per_qci
# 2022-01-30 05:15:00  2708756710728193  -                                          -                                            10
# 2022-01-31 05:45:00  2708756710728194  -                                          -                                            10
# 2022-01-31 05:30:00  2708756710728449  -                                          -                                            10
#                      2708756710728195  -                                          -                                            10
#                      2708756710728194  -                                          -                                            10
#                                                                                                                                ..
# ...

# %%
wo_hyphen=test.copy()

# %%
wo_hyphen.head()
# Out:
#             starttime              ecgi  \
# 0 2022-01-31 23:55:00  2708756710728449
# 1 2022-01-31 23:55:00  2708756710728449
# 2 2022-01-31 23:55:00  2708756710728449
# 3 2022-01-31 23:55:00  2708756710728449
# 4 2022-01-31 23:55:00  2708756710728449
#
#   min5_effective_dl_cell_throughput_per_qci  \
# 0                                         -
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -
#
#   min5_effective_ul_cell_throughput_per_qci
# 0                                         -
# 1                                         -
# 2                                         -
# 3                                         -
# 4                                         -

# %%
wo_hyphen['min5_effective_dl_cell_throughput_per_qci'].replace({'-':None})
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 46154    None
# 46155    None
# 46156    None
# 46157    None
# 46158    None
# Name: min5_effective_dl_cell_throughput_per_qci, Length: 46159, dtype: object

# %%
wo_hyphen['min5_effective_dl_cell_throughput_per_qci']=wo_hyphen['min5_effective_dl_cell_throughput_per_qci'].replace({'-':None})

# %%
wo_hyphen['min5_effective_ul_cell_throughput_per_qci'].replace({'-':None})
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 46154    None
# 46155    None
# 46156    None
# 46157    None
# 46158    None
# Name: min5_effective_ul_cell_throughput_per_qci, Length: 46159, dtype: object

# %%
wo_hyphen['min5_effective_ul_cell_throughput_per_qci']=wo_hyphen['min5_effective_ul_cell_throughput_per_qci'].replace({'-':None})

# %%
wo_hyphen['starttime'].replace({'-':None})
# Out:
# 0       2022-01-31 23:55:00
# 1       2022-01-31 23:55:00
# 2       2022-01-31 23:55:00
# 3       2022-01-31 23:55:00
# 4       2022-01-31 23:55:00
#                 ...
# 46154   2022-01-30 05:15:00
# 46155   2022-01-30 05:15:00
# 46156   2022-01-30 05:15:00
# 46157   2022-01-30 05:15:00
# 46158   2022-01-30 05:15:00
# Name: starttime, Length: 46159, dtype: datetime64[ns]

# %%
wo_hyphen['starttime']=wo_hyphen['starttime'].replace({'-':None})

# %%
wo_hyphen['ecgi'].replace({'-':None})
# Out:
# 0        2708756710728449
# 1        2708756710728449
# 2        2708756710728449
# 3        2708756710728449
# 4        2708756710728449
#                ...
# 46154    2708756710728450
# 46155    2708756710728450
# 46156    2708756710728450
# 46157    2708756710728450
# 46158    2708756710728450
# Name: ecgi, Length: 46159, dtype: category
# Categories (9, int64): [2708756710728193, 2708756710728194, 2708756710728195, 2708756710728449, ...,
#                         2708756710728451, 2708756710728705, 2708756710728706, 2708756710728707]

# %%
wo_hyphen['ecgi']=wo_hyphen['ecgi'].replace({'-':None})

# %%
wo_hyphen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46159 entries, 0 to 46158
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   starttime                                  46159 non-null  datetime64[ns]
#  1   ecgi                                       46159 non-null  category
#  2   min5_effective_dl_cell_throughput_per_qci  1933 non-null   object
#  3   min5_effective_ul_cell_throughput_per_qci  1877 non-null   object
# dtypes: category(1), datetime64[ns](1), object(2)
# memory usage: 1.1+ MB

# %%
wo_hyphen.value_counts()
# Out:
# starttime            ecgi              min5_effective_dl_cell_throughput_per_qci  min5_effective_ul_cell_throughput_per_qci
# 2022-01-30 21:50:00  2708756710728193  0                                          0                                            2
# 2022-01-30 10:55:00  2708756710728707  0                                          0                                            2
# 2022-01-30 22:50:00  2708756710728193  0                                          0                                            2
# 2022-01-31 07:30:00  2708756710728193  0                                          0                                            2
# 2022-01-31 01:40:00  2708756710728193  0                                          0                                            2
#                                                                                                                               ..
# ...

# %%
cells=wo_hyphen['ecgi'].unique()

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
#for cell in cells:
#  data = wo_hyphen[wo_hyphen['min5_effective_dl_cell_throughput_per_qci'] == cell]
#  try:
#    sns.violinplot(data['min5_effective_dl_cell_throughput_per_qci'])
#    plt.show()
#  except:
#    pass

# %%
for cell in cells:
  data = wo_hyphen[wo_hyphen['ecgi'] == cell]
  try:
    plt.figure(figsize = (8,6))
    plt.plot(data['pdcp_user_data_volume_dl_all_qci'],label = cell,marker = 'o',markerfacecolor = 'red')
    plt.legend()
    plt.show()
  except:
    pass
  break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2475c2b304f8> in <module>()
# ----> 1 for cell in cells:
#       2   data = wo_hyphen[wo_hyphen['ecgi'] == cell]
#       3   try:
#       4     plt.figure(figsize = (8,6))
#       5     plt.plot(data['pdcp_user_data_volume_dl_all_qci'],label = cell,marker = 'o',markerfacecolor = 'red')
#
# NameError: name 'cells' is not defined
