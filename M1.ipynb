# %% [markdown]
# # **Intial Preparation of Data and Data Cleaning**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('F_Active_Ues.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f18a479d4ceb> in <module>()
# ----> 1 df = pd.read_csv('F_Active_Ues.csv')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
# dataframe without (w/o) meta data with cell name
df_wo_meta=df[['starttime','ecgi', 'active_ues_with_data_beaerer', 'active_and_idle_ues', 'min5_active_ues_with_data_beaerer', 'min5_active_and_idle_ues']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c17819535bab> in <module>()
#       1 # dataframe without (w/o) meta data with cell name
# ----> 2 df_wo_meta=df[['starttime','ecgi', 'active_ues_with_data_beaerer', 'active_and_idle_ues', 'min5_active_ues_with_data_beaerer', 'min5_active_and_idle_ues']]
#
# NameError: name 'df' is not defined

# %%
df_wo_meta.head(11)
# Out:
#                ecgi cell_name
# 0  2708756710728193     VME11
# 1  2708756710728449     VME21
# 2  2708756710728194     VME12
# 3  2708756710728707     VME33
# 4  2708756710728706     VME32
# 5  2708756710728450     VME22
# 6  2708756710728195     VME13
# 7  2708756710728451     VME23
# 8  2708756710728705     VME31
