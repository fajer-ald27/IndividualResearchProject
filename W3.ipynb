# %%
data=df[df['ecgi']==2708756710728193]

# %%
data.head()
# Out:
#     Unnamed: 0      id            starttime                  day  \
# 3            3  637337  2021-10-28 07:20:00  2021-10-28 00:00:00
# 4            4  637314  2021-10-28 07:20:00  2021-10-28 00:00:00
# 5            5  650189  2021-11-01 01:20:00  2021-11-01 00:00:00
# 8            8  621353  2021-10-24 05:45:00  2021-10-24 00:00:00
# 10          10  611988  2021-10-22 05:05:00  2021-10-22 00:00:00
#
#                 ecgi  cuid  plr_cuid  duid  plr_cellid  \
# 3   2708756710728193     0         1     1           0
# 4   2708756710728193     1         1     0           0
# 5   2708756710728193     0         0     1           1
# 8   2708756710728193     1         1     0           0
# 10  2708756710728193     0         0     1           1
#
#     min5_average_pdcp_sdu_delay_dl  min5_average_pdcp_sdu_drop_rate_dl  \
# 3                         0.000000                                 0.0
# 4                         0.000000                                 0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7555 entries, 3 to 10562
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Unnamed: 0                            7555 non-null   int64
#  1   id                                    7555 non-null   int64
#  2   starttime                             7555 non-null   object
#  3   day                                   7555 non-null   object
#  4   ecgi                                  7555 non-null   int64
#  5   cuid                                  7555 non-null   int64
#  6   plr_cuid                              7555 non-null   int64
#  7   duid                                  7555 non-null   int64
#  8   plr_cellid                            7555 non-null   int64
#  9   min5_average_pdcp_sdu_delay_dl        7555 non-null   float64
#  10  min5_average_pdcp_sdu_drop_rate_dl    7555 non-null   float64
# ...

# %%
df=pd.read_csv("Workshop.csv")

# %%
x=data[['starttime','min5_pdcp_packets_lost_rate_dl','min5_pdcp_packets_lost_rate_ul']]

# %%
x.head()
# Out:
#               starttime  min5_pdcp_packets_lost_rate_dl  \
# 3   2021-10-28 07:20:00                        0.000000
# 4   2021-10-28 07:20:00                        0.000000
# 5   2021-11-01 01:20:00                        0.000000
# 8   2021-10-24 05:45:00                        0.034483
# 10  2021-10-22 05:05:00                        0.000000
#
#     min5_pdcp_packets_lost_rate_ul
# 3                         0.000000
# 4                         0.000000
# 5                         0.000000
# 8                         0.002637
# 10                        0.000000

# %%
x['starttime']=pd.to_datetime(x['starttime'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x.sort_values('starttime')
# Out:
#                starttime  min5_pdcp_packets_lost_rate_dl  \
# 2153 2021-10-18 11:35:00                        0.000000
# 2156 2021-10-18 11:40:00                        0.000000
# 2157 2021-10-18 11:40:00                        0.000000
# 8942 2021-10-18 11:40:00                        0.047207
# 8941 2021-10-18 11:40:00                        0.047207
# ...                  ...                             ...
# 944  2021-11-01 08:45:00                        0.000000
# 993  2021-11-01 08:50:00                        0.000000
# 953  2021-11-01 08:55:00                        0.000000
# 1015 2021-11-01 09:00:00                        0.000000
# 1021 2021-11-01 09:05:00                        0.000000
#
#       min5_pdcp_packets_lost_rate_ul
# 2153                        0.044942
# 2156                        0.075869
# 2157                        0.075869
# 8942                        0.000000
# 8941                        0.000000
# ...                              ...
# ...

# %%
x=x.sort_values('starttime')

# %%
x.index=x.starttime

# %%
y=x.drop('starttime',axis=1)

# %%
y.head()
# Out:
#                      min5_pdcp_packets_lost_rate_dl  \
# starttime
# 2021-10-18 11:35:00                        0.000000
# 2021-10-18 11:40:00                        0.000000
# 2021-10-18 11:40:00                        0.000000
# 2021-10-18 11:40:00                        0.047207
# 2021-10-18 11:40:00                        0.047207
#
#                      min5_pdcp_packets_lost_rate_ul
# starttime
# 2021-10-18 11:35:00                        0.044942
# 2021-10-18 11:40:00                        0.075869
# 2021-10-18 11:40:00                        0.075869
# 2021-10-18 11:40:00                        0.000000
# 2021-10-18 11:40:00                        0.000000

# %%
import matplotlib.pyplot as plt

y.plot(rot=90)

# %%
plt.xticks(rotation=90)
plt.plot(y['min5_pdcp_packets_lost_rate_ul'])

# %%
plt.xticks(rotation=90)
plt.plot(y['min5_pdcp_packets_lost_rate_dl'])

# %%
import seaborn as sns

# %%
sns.scatterplot(x='starttime',y='min5_pdcp_packets_lost_rate_ul',data=y)
