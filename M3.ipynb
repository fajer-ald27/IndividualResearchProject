# %% [markdown]
# # **Intial Preparation of Data and Data Cleaning**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Cell_mapping.csv')

# %%
df.head()
# Out:
#     cell_name_n    cell_name_d cell_name_short              ecgi cell_name  \
# 0  999991000021  99F999186A201         186A201  2708756710728193     VME11
# 1  999991000031  99F999186A301         186A301  2708756710728449     VME21
# 2  999991000022  99F999186A202         186A202  2708756710728194     VME12
# 3  999991000043  99F999186A403         186A403  2708756710728707     VME33
# 4  999991000042  99F999186A402         186A402  2708756710728706     VME32
#
#      cellid  cell_short_id   pci  sector  site full_site_name
# 0  25600513          41473  PCI1       1     1       ME-E14_A
# 1  25600769          41729  PCI4       1     2       ME-H14_A
# 2  25600514          41474  PCI2       2     1       ME-E14_B
# 3  25601027          41987  PCI9       3     3       ME-E05_C
# 4  25601026          41986  PCI8       2     3       ME-E05_B

# %%
# dataframe without (w/o) meta data with cell name
df_wo_meta=df[['ecgi','cell_name']]

# %%
df_wo_meta.head(11)
# Out:
#                ecgi cell_name
# 0  2708756710728193     VME11
# 1  2708756710728449     VME21
# 2  2708756710728194     VME12
# 3  2708756710728707     VME33
# 4  2708756710728706     VME32
# 5  2708756710728450     VME22
# 6  2708756710728195     VME13
# 7  2708756710728451     VME23
# 8  2708756710728705     VME31
